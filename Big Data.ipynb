# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
superstore = pd.read_csv("/content/dataset_Superstore.csv")
superstore.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0    3783  CA-2017-165204  13/11/2017  16/11/2017    Second Class    MN-17935
# 1    7322  CA-2017-167626  03/09/2017  07/09/2017  Standard Class    MY-18295
# 2    1709  CA-2017-123491  30/10/2017  05/11/2017  Standard Class    JK-15205
# 3    2586  CA-2015-121041  03/11/2015  10/11/2015  Standard Class    CS-12250
# 4     356  CA-2016-138520  08/04/2016  13/04/2016  Standard Class    JL-15505
#
#      Customer Name  Customer_no    Segment  Segment_no  ... Category_no  \
# 0   Michael Nguyen            1   Consumer           1  ...           2
# 1  Muhammed Yedwab            2  Corporate           2  ...           2
# 2     Jamie Kunitz            3   Consumer           1  ...           2
# 3  Chris Selesnick            4  Corporate           2  ...           2
# 4  Jeremy Lonsdale            5   Consumer           1  ...           2
#
#   Sub-Category Sub-Category_no  \
# ...

# %%
print(superstore)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0       3783  CA-2017-165204  13/11/2017  16/11/2017    Second Class
# 1       7322  CA-2017-167626  03/09/2017  07/09/2017  Standard Class
# 2       1709  CA-2017-123491  30/10/2017  05/11/2017  Standard Class
# 3       2586  CA-2015-121041  03/11/2015  10/11/2015  Standard Class
# 4        356  CA-2016-138520  08/04/2016  13/04/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    2121  US-2017-168690  07/01/2017  13/01/2017  Standard Class
# 9990    5274  US-2016-158309  26/11/2016  29/11/2016     First Class
# 9991    7312  CA-2015-162761  09/10/2015  13/10/2015  Standard Class
# 9992    2219  CA-2017-130841  28/07/2017  01/08/2017  Standard Class
# 9993     962  CA-2015-160059  27/11/2015  01/12/2015  Standard Class
#
#      Customer ID    Customer Name  Customer_no      Segment  Segment_no  ...  \
# ...

# %%
superstore.shape
# Out:
# (9994, 29)

# %%
superstore.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Customer_no', 'Segment', 'Segment_no',
#        'Country', 'City', 'State', 'State_no', 'Postal Code', 'Region',
#        'Region_no', 'Product ID', 'Category', 'Category_no', 'Sub-Category',
#        'Sub-Category_no', 'Product Name', 'Product Name_no', 'Sales',
#        'Quantity', 'Discount', 'Profit', 'Returned'],
#       dtype='object')

# %%
duplicate_rows_superstore = superstore[superstore.duplicated]
print("Number of Duplicate Rows: ",duplicate_rows_superstore.shape)
# Out:
# Number of Duplicate Rows:  (0, 29)

# %%
superstore.shape
# Out:
# (9994, 29)

# %%
superstore.isnull().sum()
# Out:
# Row ID             0
# Order ID           0
# Order Date         0
# Ship Date          0
# Ship Mode          0
# Customer ID        0
# Customer Name      0
# Customer_no        0
# Segment            0
# Segment_no         0
# Country            0
# City               0
# State              0
# State_no           0
# Postal Code        0
# Region             0
# Region_no          0
# Product ID         0
# Category           0
# Category_no        0
# Sub-Category       0
# Sub-Category_no    0
# Product Name       0
# Product Name_no    0
# Sales              0
# Quantity           0
# Discount           0
# Profit             0
# Returned           0
# dtype: int64

# %%
superstore.describe()
# Out:
#             Row ID  Customer_no   Segment_no     State_no   Postal Code  \
# count  9994.000000  9994.000000  9994.000000  9994.000000   9994.000000
# mean   4997.500000   351.686312     1.658995    23.343206  55190.379428
# std    2885.163629   218.420565     0.762622    15.504611  32063.693350
# min       1.000000     1.000000     1.000000     1.000000   1040.000000
# 25%    2499.250000   164.000000     1.000000     5.000000  23223.000000
# 50%    4997.500000   338.000000     1.000000    28.000000  56430.500000
# 75%    7495.750000   534.000000     2.000000    37.000000  90008.000000
# max    9994.000000   793.000000     3.000000    49.000000  99301.000000
#
#          Region_no  Category_no  Sub-Category_no  Product Name_no  \
# count  9994.000000  9994.000000      9994.000000      9994.000000
# mean      2.587753     1.972584         7.356414       922.312287
# std       1.015616     0.629544         4.544260       531.671404
# ...

# %%
superstore['Sales_r'] = round(superstore['Sales'], 2)
superstore['Profit_r'] = round(superstore['Profit'], 2)
cols = ['Sales','Profit']
superstore.drop(cols, axis=1, inplace=True)

# %%
insignificant=['Row ID','Order ID','Ship Mode','Customer Name','Customer_no','Country','State_no','Postal Code','Region_no']
superstore.drop(insignificant, axis=1, inplace=True)

# %%
superstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order Date       9994 non-null   object
#  1   Ship Date        9994 non-null   object
#  2   Customer ID      9994 non-null   object
#  3   Segment          9994 non-null   object
#  4   Segment_no       9994 non-null   int64
#  5   City             9994 non-null   object
#  6   State            9994 non-null   object
#  7   Region           9994 non-null   object
#  8   Product ID       9994 non-null   object
#  9   Category         9994 non-null   object
#  10  Category_no      9994 non-null   int64
#  11  Sub-Category     9994 non-null   object
#  12  Sub-Category_no  9994 non-null   int64
#  13  Product Name     9994 non-null   object
#  14  Product Name_no  9994 non-null   int64
#  15  Quantity         9994 non-null   int64
#  16  Discount         9994 non-null   float64
# ...

# %%
superstore
# Out:
#       Order Date   Ship Date Customer ID      Segment  Segment_no  \
# 0     13/11/2017  16/11/2017    MN-17935     Consumer           1
# 1     03/09/2017  07/09/2017    MY-18295    Corporate           2
# 2     30/10/2017  05/11/2017    JK-15205     Consumer           1
# 3     03/11/2015  10/11/2015    CS-12250    Corporate           2
# 4     08/04/2016  13/04/2016    JL-15505     Consumer           1
# ...          ...         ...         ...          ...         ...
# 9989  07/01/2017  13/01/2017    TS-21085     Consumer           1
# 9990  26/11/2016  29/11/2016    PA-19060  Home Office           3
# 9991  09/10/2015  13/10/2015    SC-20575     Consumer           1
# 9992  28/07/2017  01/08/2017    MH-17620    Corporate           2
# 9993  27/11/2015  01/12/2015    TB-21190  Home Office           3
#
#                City       State   Region       Product ID         Category  \
# 0           Memphis   Tennessee    South  OFF-PA-10003424  Office Supplies
# ...

# %%
returned_orders = superstore[superstore['Returned'] == True]
superstore = superstore.drop(returned_orders.index)

# %%
superstore.describe()
# Out:
#         Segment_no  Category_no  Sub-Category_no  Product Name_no  \
# count  9194.000000  9194.000000      9194.000000      9194.000000
# mean      1.662932     1.971829         7.352730       918.070916
# std       0.765459     0.628704         4.541014       531.686756
# min       1.000000     1.000000         1.000000         1.000000
# 25%       1.000000     2.000000         4.000000       471.000000
# 50%       1.000000     2.000000         7.000000       902.000000
# 75%       2.000000     2.000000        11.000000      1382.000000
# max       3.000000     3.000000        17.000000      1849.000000
#
#            Quantity     Discount       Sales_r     Profit_r
# count   9194.000000  9194.000000   9194.000000  9194.000000
# mean       7.048401     0.157532    230.225841    28.623481
# std      180.563348     0.207779    623.570060   228.173622
# min        1.000000     0.000000      0.440000 -6599.980000
# 25%        2.000000     0.000000     16.780000     1.670000
# ...

# %%
cols=['Quantity','Sales_r','Profit_r']
plt.figure(figsize=[10,5])
sns.set(style="whitegrid")
ax = sns.boxplot(data=superstore[cols])
plt.title('Box Plot To Find Outliers')
plt.show()

# %%
numeric_cols = superstore[['Sales_r', 'Profit_r', 'Quantity']]
Q1 = numeric_cols.quantile(0.25)
Q3 = numeric_cols.quantile(0.75)
IQR = Q3 - Q1
Outliers = np.any((numeric_cols < (Q1 - 1.5 * IQR)) | (numeric_cols > (Q3 + 1.5 * IQR)), axis=1)
print("Number of outliers detected:", Outliers.sum())
superstore = superstore[~Outliers]
# Out:
# Number of outliers detected: 2038

# %%
cols=['Quantity','Sales_r','Profit_r']
plt.figure(figsize=[10,5])
sns.set(style="whitegrid")
ax = sns.boxplot(data=superstore[cols])
plt.title('Box Plot to Find Outliers')
plt.show()

# %%
superstore.mean()
# Out:
# <ipython-input-19-d442cf498d13>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   superstore.mean()
# Segment_no           1.658608
# Category_no          1.977362
# Sub-Category_no      6.713667
# Product Name_no    921.968139
# Quantity             3.416154
# Discount             0.148946
# Returned             0.000000
# Sales_r             69.901543
# Profit_r            11.012982
# dtype: float64

# %%
superstore.median()
# Out:
# <ipython-input-20-cad59a00d514>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   superstore.median()
# Segment_no           1.00
# Category_no          2.00
# Sub-Category_no      6.00
# Product Name_no    930.00
# Quantity             3.00
# Discount             0.20
# Returned             0.00
# Sales_r             32.92
# Profit_r             6.91
# dtype: float64

# %%
superstore.describe()
# Out:
#         Segment_no  Category_no  Sub-Category_no  Product Name_no  \
# count  7156.000000  7156.000000      7156.000000      7156.000000
# mean      1.658608     1.977362         6.713667       921.968139
# std       0.765155     0.572895         4.250906       553.406598
# min       1.000000     1.000000         1.000000         1.000000
# 25%       1.000000     2.000000         4.000000       449.500000
# 50%       1.000000     2.000000         6.000000       930.000000
# 75%       2.000000     2.000000         9.000000      1428.500000
# max       3.000000     3.000000        17.000000      1849.000000
#
#           Quantity     Discount      Sales_r     Profit_r
# count  7156.000000  7156.000000  7156.000000  7156.000000
# mean      3.416154     0.148946    69.901543    11.012982
# std       1.884161     0.200294    89.712588    17.839427
# min       1.000000     0.000000     0.440000   -39.640000
# 25%       2.000000     0.000000    13.090000     2.020000
# ...

# %%
 superstore.Category.value_counts(ascending=False)
# Out:
# Office Supplies    4804
# Furniture          1257
# Technology         1095
# Name: Category, dtype: int64

# %%
sns.countplot(x='Category', palette='Set2', data=superstore)
plt.title('Bar Graph of Product Categories')
plt.show()
# Out:
# <ipython-input-23-9da6e70c7095>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Category', palette='Set2', data=superstore)

# %%
superstore.Segment.value_counts(ascending=False)
# Out:
# Consumer       3733
# Corporate      2133
# Home Office    1290
# Name: Segment, dtype: int64

# %%
sns.countplot(x='Segment', palette="Set3", data=superstore)
plt.title('Bar Graph of Product Segments')
plt.show()
# Out:
# <ipython-input-25-c9b9cce23414>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Segment', palette="Set3", data=superstore)

# %%
sns.catplot(x= 'Segment', y='Profit_r', kind= 'bar', hue='Category', palette='Set1', data=superstore)
plt.title('Bar Graph Depicting Profit Margin of Consumer Segments and Product Categories')
plt.show()

# %%
plt.figure(figsize=(13,8))
sns.catplot(x='State', y='Profit_r', data=superstore, kind='bar', height=5, aspect=2, palette='Set2')
plt.xticks(rotation=90, fontsize=13)
plt.yticks(fontsize=10)
plt.title('Bar Graph Depicting Profit Margin of Different States')
plt.show()
# Out:
# <ipython-input-27-671af240c802>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x='State', y='Profit_r', data=superstore, kind='bar', height=5, aspect=2, palette='Set2')

# %%
plt.figure(figsize=(18,10))
sns.catplot(x='Sub-Category', y='Profit_r', data=superstore, kind='bar', height=5, aspect=2, palette='Set1')
plt.xticks(rotation=90, fontsize=13)
plt.yticks(fontsize=10)
plt.title('Bar Graph Depicting Profit Margin of Different Product Sub-Category')
plt.show()
# Out:
# <ipython-input-28-c582297e6b9c>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x='Sub-Category', y='Profit_r', data=superstore, kind='bar', height=5, aspect=2, palette='Set1')

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x='Discount', y='Profit_r', hue='Category', data=superstore, palette='Set2')
plt.title('Line Plot of Relationship Between Discount and Profit')
plt.xlabel('Discount')
plt.ylabel('Profit')
plt.show()

# %%
plt.scatter(superstore['Sales_r'], superstore['Profit_r'])
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.title('Profit vs. Sales')
plt.show()

# %%
plt.scatter(superstore['Quantity'], superstore['Profit_r'])
plt.xlabel('Quantity')
plt.ylabel('Profit')
plt.title('Profit vs Quantity')
plt.show()

# %%
plt.scatter(superstore['Discount'], superstore['Profit_r'])
plt.xlabel('Discount')
plt.ylabel('Profit')
plt.title('Profit vs Discount')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import train_test_split
import seaborn as sns

# %%
x = superstore[['Sales_r', 'Quantity', 'Discount']]
y = superstore['Profit_r']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print ("Coefficient: ", model.coef_)
print("Intercept: ", model.intercept_)
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
print('r^2 score:', r2)
print('Mean Squared Error:', mse)
plt.scatter(y_test, y_pred)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2)
plt.xlabel('Actual Profit')
plt.ylabel('Predicted Profit')
plt.title('Linear Regression Model: Actual vs Predicted Profit\nR-squared = {:.2f}'.format(r2))
plt.show()
# Out:
# Coefficient:  [  0.07564142   1.37385215 -36.63471747]
# Intercept:  6.552481309916408
# r^2 score: 0.3543055565406492
# Mean Squared Error: 202.95547850881846

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
import numpy as np
import pandas as pd

# %%
x = superstore[['Sales_r', 'State', 'Sub-Category', 'Segment', 'Quantity']]
y = superstore['Profit_r']
x = pd.DataFrame(x)
preprocessor = ColumnTransformer(transformers=[('State', OneHotEncoder(),['State']),
                                               ('SubCat', OneHotEncoder(), ['Sub-Category']),
                                               ('Seg', OneHotEncoder(),['Segment'])], remainder='passthrough')
x = preprocessor.fit_transform(x)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print("Coefficient: ", model.coef_)
print("Intercept: ", model.intercept_)
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
print('R^2 Score:', r2)
print('Mean Squared  Error:', mse)
plt.scatter(y_test, y_pred)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2)
plt.xlabel('Actual Profit')
plt.ylabel('Predicted Profit')
plt.title('Linear Regression Model: Actual vs. Predicted Profit\nr-squared = {:.2f}'.format(r2))
plt.show()
# Out:
# Coefficient:  [-2.09699116e+00 -9.82981105e+00  4.11626617e+00 -5.70890113e-01
#  -1.02501488e+01  1.60178931e+00  4.34199810e+00 -2.74014448e+00
#  -1.08749084e+01  3.05661778e+00 -2.64435703e+00 -1.17728448e+01
#   3.84871092e+00  1.00222568e+00 -2.52617233e-01  3.44092416e+00
#  -9.79287265e-04  3.30153694e+00  6.89154262e+00  3.47650254e+00
#   4.66601307e+00  4.46354210e+00  4.44571462e+00  2.14117357e+00
#   2.21791540e-01  2.25342171e+00  8.22231531e+00  5.26356883e+00
#   2.60886988e+00 -8.72593870e-01  1.37834405e+00 -9.50753832e+00
#   1.53635359e+00 -1.12615643e+01  7.04039051e+00 -6.25861244e+00
#  -1.27459552e+01  3.46839586e+00  1.56630351e+00  6.27512555e+00
#  -1.06782385e+01 -1.17563136e+01  4.59806864e+00  2.94402226e+00
#   3.05827189e+00 -5.69657453e-01  9.68776253e+00  3.76660270e+00
#   7.81430073e+00  7.53823952e+00  3.69737330e+00  2.09688604e+00
#  -1.82257840e+01 -1.74149528e+01  1.99977589e+00  1.28516552e+01
# ...
